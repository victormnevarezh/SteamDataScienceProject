# %%
# Import of pandas and numpy
import pandas as pd
import numpy as np

# %%
# In here we are getting the enconder
import chardet
file = 'U:\SteamDataScienceProject\Valve_Player_Data.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
# result

# %%
# In here we are retreaving the csv's info and getting in into a DataFrame
playerData = pd.read_csv(file, encoding='ISO-8859-1')
# playerData

# %%
# In here we are creating a subset, getting rid of the URL column
usefulData = playerData[["Game_Name", "Month_Year", "Avg_players", "Gain", "Percent_Gain", "Peak_Players", "Date"]]
usefulData
# Out:
#                              Game_Name      Month_Year  Avg_players  \
# 0     Counter Strike: Global Offensive  September 2021    512350.92
# 1     Counter Strike: Global Offensive     August 2021    512081.96
# 2     Counter Strike: Global Offensive       July 2021    506067.36
# 3     Counter Strike: Global Offensive       June 2021    549347.08
# 4     Counter Strike: Global Offensive          may-21    659888.89
# ...                                ...             ...          ...
# 5266          Divinity: Original Sin 2   December 2016       192.03
# 5267          Divinity: Original Sin 2   November 2016       213.92
# 5268          Divinity: Original Sin 2    October 2016       348.60
# 5269          Divinity: Original Sin 2  September 2016       550.36
# 5270          Divinity: Original Sin 2     August 2016         7.10
#
#            Gain Percent_Gain  Peak_Players        Date
# 0        268.96        0.05%        942519  01/09/2021
# ...

# %%
# Replace
usefulData.replace()
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-21', 'May 2021', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-20', 'May 2020', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-19', 'May 2019', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-18', 'May 2018', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-17', 'May 2017', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-16', 'May 2016', inplace=True)
usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-15', 'May 2015', inplace=True)
usefulData
# Out:
# C:\Users\victo_hhsj\AppData\Local\Temp\ipykernel_8412\3691514647.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-21', 'May 2021', inplace=True)
# C:\Users\victo_hhsj\AppData\Local\Temp\ipykernel_8412\3691514647.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usefulData['Month_Year'].mask(usefulData['Month_Year'] == 'may-20', 'May 2020', inplace=True)
# C:\Users\victo_hhsj\AppData\Local\Temp\ipykernel_8412\3691514647.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Pandas split function
