# %%
# Import of pandas and numpy
import pandas as pd
import numpy as np

# Import of seaborn and matplotlib
import seaborn as sns 
import matplotlib.pyplot as plt

# Import from sklearn the linear_model
from sklearn import datasets, linear_model

# %%
# In here we are getting the enconder
import chardet
file = 'U:\SteamDataScienceProject\Valve_Player_Data.csv'
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
# result

# %%
# In here we are retreaving the csv's info and getting in into a DataFrame
playerData = pd.read_csv(file, encoding='ISO-8859-1')

# To check all of the NaN values inside the dataframe
# playerData[playerData.isna().any(axis=1)]

# It is needed to drop the NaN values not get the anaylisis influenced by them
playerData = playerData.dropna()
playerData
# Out:
#           Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0     September 2021    512350.92     268.96        0.05%        942519
# 1        August 2021    512081.96    6014.60        1.19%        802544
# 2          July 2021    506067.36  -43279.72       -7.88%        763523
# 3          June 2021    549347.08 -110541.81      -16.75%        929940
# 4             may-21    659888.89  -63457.63       -8.77%       1087197
# ...              ...          ...        ...          ...           ...
# 5265    January 2017       206.26      14.23        7.41%           429
# 5266   December 2016       192.03     -21.90      -10.24%           405
# 5267   November 2016       213.92    -134.68      -38.63%           537
# 5268    October 2016       348.60    -201.75      -36.66%          1031
# 5269  September 2016       550.36     543.26     7654.89%          2836
#
#                                      URL        Date  \
# ...

# %%
# It is needed to drop the na values just in case to avoid errors
playerData.dropna(inplace = True)

# %%
# In here we are creating a subset, getting rid of the URL column
data = playerData[["Game_Name", "Avg_players", "Gain",
                     "Percent_Gain", "Peak_Players", "Date"]]
# usable

# %%
# We are setting the right format, this being yy-mm-dd
data["Date"] = pd.to_datetime(data["Date"], format='%d/%m/%Y').dt.strftime('%Y-%m-%d')
# usable
# Out:
# C:\Users\victo_hhsj\AppData\Local\Temp\ipykernel_880\758125239.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Date"] = pd.to_datetime(data["Date"], format='%d/%m/%Y').dt.strftime('%Y-%m-%d')

# %%
# Obtain rows of the dataframe based on their date
data2021 = data.loc[(data['Date'] >= '2021-01-01')]

# %%
# Check if there are any nulls
# data2021.isnull().sum()

# %%
# Order in which things are being done here: 
# 1. I am creating a subset that only includes game_name and Avg_players
# 2. I am grouping them by Game_Name and getting the mean of each
# 3. I am sorting them by Avg_Players, from biggest to smaller
data2021Players = data2021[["Game_Name", "Avg_players"]].groupby(['Game_Name']).mean().sort_values(by='Avg_players', ascending=False)
# data2021Players

# %%
# data2021Players['Avg_players'].sum()
# Here the total avg players was: 3330071

# %%
data2021Top = data2021Players.head(7)
data2021Top['Avg_players'].sum()

data2021Top
# Out:
#                                     Avg_players
# Game_Name
# Counter Strike: Global Offensive  632025.938889
# Dota 2                            413063.873333
# PUBG: Battlegrounds               186849.945556
# Apex Legends                      131642.297778
# Grand Theft Auto V                 95682.135556
# Rust                               91743.410000
# Team Fortress 2                    88783.586667

# %%
dataAllTime = data[["Game_Name", "Avg_players"]].groupby(['Game_Name']).mean().sort_values(by='Avg_players', ascending=False)
dataAllTimeTop = dataAllTime.head(7)

dataAllTimeTop
# Out:
#                                     Avg_players
# Game_Name
# Dota 2                            454686.103727
# PUBG: Battlegrounds               451871.999444
# Counter Strike: Global Offensive  330019.465636
# Apex Legends                      124925.043000
# Destiny 2                          66768.013913
# Grand Theft Auto V                 65219.183766
# NARAKA: BLADEPOINT                 64272.230000
